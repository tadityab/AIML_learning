# %% [markdown]
# # Pandas Mastery Notebook (Beginner + Interview Preparation)
#
# Prepared as if taught by a Senior AI/ML Engineer and Instructor.
#
# ## Learning Outcomes
# - Understand Pandas fundamentals
# - Work with Series and DataFrames
# - Perform indexing and data selection
# - Prepare for interviews with practice questions

# %% [markdown]
# # Introduction to Pandas
#
# Pandas is an open-source Python library used for data manipulation and analysis.
#
# ## Characteristics of Pandas
# - Data Handling: Manage missing values and structured data.
# - Performance: Built on NumPy for efficient operations.
# - Flexibility: Supports multiple data sources.
# - Integration: Works with NumPy, Matplotlib, Scikit-learn.
# - User-Friendly API: Easy-to-read syntax.

# %%
# %pip install pandas
# Out:
# ...
#   Using cached pandas-2.0.3-cp38-cp38-win_amd64.whl (10.8 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
# Out:
# 2.0.3

# %% [markdown]
# # Series
#
# A Series is a one-dimensional labelled array capable of holding heterogeneous data.
#
# ## Components
# - Data
# - Index
# - Data Type
#
# ## Facts
# - Mutable values
# - Immutable size
# - Supports vectorized operations

# %%
# Create Series from list
s1 = pd.Series([10,20,30], index=['a','b','c'])
print(s1)

# Create Series from dictionary
s2 = pd.Series({'Math':90,'Science':95,'English':88})
print(s2)
# Out:
# a    10
# b    20
# c    30
# dtype: int64
# Math       90
# Science    95
# English    88
# dtype: int64

# %% [markdown]
# # DataFrame
#
# A DataFrame is a two-dimensional labelled data structure.
#
# ## Properties
# 1. Heterogeneous Data
# 2. Size Mutable
# 3. Labelled Axes
# 4. Supports Missing Values
# 5. Powerful Indexing

# %%
# List of lists
df1 = pd.DataFrame(
    [['John',25],['Mary',30]],
    columns=['Name','Age']
)
print(df1)

# List of dictionaries
df2 = pd.DataFrame([
    {'Name':'Alice','Age':28},
    {'Name':'Bob','Age':35}
])
print(df2)

# Dictionary of Series
df3 = pd.DataFrame({
    'A': pd.Series([1,2,3]),
    'B': pd.Series([4,5,6])
})
print(df3)
# Out:
#    Name  Age
# 0  John   25
# 1  Mary   30
#     Name  Age
# 0  Alice   28
# 1    Bob   35
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %% [markdown]
# # Adding Columns
#
# Methods:
# - Assign scalar value
# - Assign list
# - Assign Series

# %%
df = pd.DataFrame({
    'Name':['John','Mary','Alice'],
    'Age':[25,30,28]
})

# Scalar
df['Country'] = 'India'

# List
df['Score'] = [80,90,85]

# Series
bonus = pd.Series([5,10,15])
df['Bonus'] = bonus

print(df)
# Out:
#     Name  Age Country  Score  Bonus
# 0   John   25   India     80      5
# 1   Mary   30   India     90     10
# 2  Alice   28   India     85     15

# %% [markdown]
# # Rename Columns
#
# rename(columns={}, inplace=False)
#
# Parameters:
# - columns
# - inplace

# %%
# Rename single column
df.rename(columns={'Age':'Employee_Age'}, inplace=True)

# Rename multiple columns
df.rename(columns={
    'Score':'Exam_Score',
    'Bonus':'Extra_Bonus'
}, inplace=True)

print(df)
# Out:
#     Name  Employee_Age Country  Exam_Score  Extra_Bonus
# 0   John            25   India          80            5
# 1   Mary            30   India          90           10
# 2  Alice            28   India          85           15

# %% [markdown]
# # Indexing and Data Selection
#
# ## Types
# - loc (label based)
# - iloc (position based)

# %%
employees = pd.DataFrame({
    'Name':['John','Mary','Alice','Bob'],
    'Department':['IT','HR','IT','Finance'],
    'Salary':[50000,60000,55000,70000]
}, index=['E1','E2','E3','E4'])

print(employees)
# Out:
#      Name Department  Salary
# E1   John         IT   50000
# E2   Mary         HR   60000
# E3  Alice         IT   55000
# E4    Bob    Finance   70000

# %% [markdown]
# ## loc Examples

# %%
# Access row
print(employees.loc['E1'])

# Access column
print(employees.loc[:, 'Name'])

# Multiple rows and columns
print(employees.loc[['E1','E3'], ['Name','Salary']])

# Conditional indexing
print(employees.loc[employees['Salary'] > 55000])
# Out:
# Name           John
# Department       IT
# Salary        50000
# Name: E1, dtype: object
# E1     John
# E2     Mary
# E3    Alice
# E4      Bob
# Name: Name, dtype: object
#      Name  Salary
# E1   John   50000
# E3  Alice   55000
#     Name Department  Salary
# E2  Mary         HR   60000
# E4   Bob    Finance   70000

# %% [markdown]
# ## iloc Examples

# %%
# Single row
print(employees.iloc[0])

# Single column
print(employees.iloc[:,0])

# Subset
print(employees.iloc[0:3, 0:2])
# Out:
# Name           John
# Department       IT
# Salary        50000
# Name: E1, dtype: object
# E1     John
# E2     Mary
# E3    Alice
# E4      Bob
# Name: Name, dtype: object
#      Name Department
# E1   John         IT
# E2   Mary         HR
# E3  Alice         IT

# %% [markdown]
# # Additional Important Interview Topics
#
# ## DataFrame Attributes
# - shape
# - columns
# - index
# - dtypes
# - values
# - info()
# - describe()
#
# ## Missing Value Handling
# - isnull()
# - fillna()
# - dropna()
#
# ## Head/Tail
# - head()
# - tail()

# %%
sample = pd.DataFrame({
    'A':[1,2,np.nan],
    'B':[4,np.nan,6]
})

print(sample.info())
print(sample.describe())

print(sample.isnull())
print(sample.fillna(0))
print(sample.dropna())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       2 non-null      float64
#  1   B       2 non-null      float64
# dtypes: float64(2)
# memory usage: 176.0 bytes
# None
#               A         B
# count  2.000000  2.000000
# mean   1.500000  5.000000
# std    0.707107  1.414214
# min    1.000000  4.000000
# 25%    1.250000  4.500000
# 50%    1.500000  5.000000
# 75%    1.750000  5.500000
# max    2.000000  6.000000
#        A      B
# 0  False  False
# 1  False   True
# 2   True  False
#      A    B
# 0  1.0  4.0
# 1  2.0  0.0
# 2  0.0  6.0
#      A    B
# 0  1.0  4.0

# %% [markdown]
# # Practice Questions
#
# 1. Create a Series using a list of 5 numbers.
# 2. Create a Series using a dictionary of student marks.
# 3. Create a DataFrame using a list of dictionaries.
# 4. Add a new column using scalar values.
# 5. Add a new column using a Series.
# 6. Rename one column and multiple columns.
# 7. Use loc to select:
#    - A single row
#    - Multiple rows
#    - Conditional rows
# 8. Use iloc to select:
#    - First row
#    - Second column
#    - First three rows and two columns
# 9. Find DataFrame shape and dtypes.
# 10. Handle missing values using fillna().

# %% [markdown]
# # Interview Questions
#
# 1. Difference between Series and DataFrame?
# 2. loc vs iloc?
# 3. Why is Pandas built on NumPy?
# 4. What is heterogeneous data?
# 5. How do you rename columns?
# 6. How do you add columns?
# 7. How does Pandas handle missing values?
# 8. Explain DataFrame attributes.
# 9. Difference between list of dictionaries and dictionary of Series?
# 10. When would you choose loc over iloc?
